# %%
import requests

base = "https://external-api.demo.kalshi.co/trade-api/v2"

# %%
url = f"{base}/events?status=open&with_nested_markets=True&series_ticker=KXMLBGAME"
response = requests.get(url)
data = response.json()["events"]

# %%
data
