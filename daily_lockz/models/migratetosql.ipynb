# %%
import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv('./data/nfl_games.csv', index_col=0)
df
# Out:
#         1d    1d%  1d%_max  1d_max       adot  adot_max        air  air_max  \
# 0      7.5  67.95    100.0    14.0  10.237500      19.0  18.625000     68.0
# 1     15.0  30.60     30.6    15.0   6.355556      17.3  12.222222     53.0
# 2     16.0  37.20     37.2    16.0   9.728571      20.3  18.250000     83.0
# 3     12.0  36.40     36.4    12.0  10.300000      16.8  13.727273     35.0
# 4     12.0  29.30     29.3    12.0   6.137500      18.5  13.900000     42.0
# ...    ...    ...      ...     ...        ...       ...        ...      ...
# 3307   6.0  12.80     12.8     6.0   9.875000      33.0  17.857143     38.0
# 3308  10.0  28.60     28.6    10.0   9.055556      32.0  10.285714     41.0
# 3309   9.0  31.00     31.0     9.0   6.716667      15.4  14.555556     40.0
# 3310   9.0  19.10     19.1     9.0   5.471429      14.8  10.750000     24.0
# 3311   2.5  55.55    100.0     4.0  10.757143      36.3  23.666667     69.0
#
#            ast  ast_max  ...  yds/tgt_opp  yds/tgt_max_opp  yds_max_opp  \
# 0     1.904762      4.0  ...     8.430000             18.0        333.0
# 1     1.782609      8.0  ...     7.788889             25.7        255.0
# 2     1.437500      4.0  ...     7.472727             14.0        267.0
# 3     1.625000      5.0  ...    11.012500             28.0        273.0
# 4     0.444444      2.0  ...     5.830000             11.0        272.0
# ...        ...      ...  ...          ...              ...          ...
# 3307  1.789474      6.0  ...     4.516667             11.0        335.0
# 3308  1.142857      4.0  ...     6.233333             11.0        161.0
# 3309  1.210526      4.0  ...     5.871429              8.8        170.0
# 3310  0.772727      5.0  ...     4.210000             12.7        117.0
# 3311  0.750000      4.0  ...     3.066667              4.7        251.0
#
#                  team_opp  total_opp  \
# 0      Kansas City Chiefs         25
# 1     San Francisco 49ers         22
# 2     San Francisco 49ers         34
# 3           Detroit Lions         31
# 4        Baltimore Ravens         10
# ...                   ...        ...
# 3307  Pittsburgh Steelers         21
# 3308    Carolina Panthers         16
# 3309       Dallas Cowboys          8
# 3310  Philadelphia Eagles         18
# 3311      Atlanta Falcons         12
#
#                                                logo_opp  home_opp        date  \
# 0     https://cdn.ssref.net/req/202406281/tlogo/pfr/...         1  2024-02-11
# 1     https://cdn.ssref.net/req/202406281/tlogo/pfr/...         0  2024-02-11
# 2     https://cdn.ssref.net/req/202406281/tlogo/pfr/...         1  2024-01-28
# 3     https://cdn.ssref.net/req/202406281/tlogo/pfr/...         0  2024-01-28
# 4     https://cdn.ssref.net/req/202406281/tlogo/pfr/...         1  2024-01-28
# ...                                                 ...       ...         ...
# 3307  https://cdn.ssref.net/req/202406281/tlogo/pfr/...         0  2018-09-09
# 3308  https://cdn.ssref.net/req/202406281/tlogo/pfr/...         1  2018-09-09
# 3309  https://cdn.ssref.net/req/202406281/tlogo/pfr/...         0  2018-09-09
# 3310  https://cdn.ssref.net/req/202406281/tlogo/pfr/...         1  2018-09-06
# 3311  https://cdn.ssref.net/req/202406281/tlogo/pfr/...         0  2018-09-06
#
#       spread  total_score
# 0         -3           47
# 1          3           47
# 2         -3           65
# 3          3           65
# 4          7           27
# ...      ...          ...
# 3307       0           42
# 3308      -8           24
# 3309       8           24
# 3310      -6           30
# 3311       6           30
#
# [3312 rows x 356 columns]

# %%
engine = create_engine('postgresql://trevor@localhost:5432/daily_lockz')
df.to_sql('nfl_games', engine, if_exists='replace', index=False)
# Out:
# 36
