# %%
game = {
    "id": "ff82897598a935d7b4dabd1c4d71cd05",
    "sport_key": "soccer_denmark_superliga",
    "sport_title": "Denmark Superliga",
    "commence_time": "2026-03-01T16:00:00Z",
    "home_team": "Vejle Boldklub",
    "away_team": "AGF Aarhus",
    "bookmakers": [
        {
            "key": "pinnacle",
            "title": "Pinnacle",
            "last_update": "2026-02-25T22:14:41Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:41Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.65},
                        {"name": "Vejle Boldklub", "price": 4.93},
                        {"name": "Draw", "price": 4.07},
                    ],
                },
                {
                    "key": "spreads",
                    "last_update": "2026-02-25T22:14:41Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.83, "point": -0.75},
                        {"name": "Vejle Boldklub", "price": 2.03, "point": 0.75},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:41Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.88, "point": 2.75},
                        {"name": "Under", "price": 1.95, "point": 2.75},
                    ],
                },
            ],
        },
        {
            "key": "fanduel",
            "title": "FanDuel",
            "last_update": "2026-02-25T22:13:01Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:01Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.62},
                        {"name": "Vejle Boldklub", "price": 5.0},
                        {"name": "Draw", "price": 4.0},
                    ],
                }
            ],
        },
        {
            "key": "nordicbet",
            "title": "Nordic Bet",
            "last_update": "2026-02-25T22:13:59Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:59Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.65},
                        {"name": "Vejle Boldklub", "price": 4.8},
                        {"name": "Draw", "price": 4.05},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:13:59Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.65, "point": 2.5},
                        {"name": "Under", "price": 2.18, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "marathonbet",
            "title": "Marathon Bet",
            "last_update": "2026-02-25T22:14:11Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:11Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.61},
                        {"name": "Vejle Boldklub", "price": 5.0},
                        {"name": "Draw", "price": 4.0},
                    ],
                }
            ],
        },
        {
            "key": "parionssport_fr",
            "title": "Parions Sport (FR)",
            "last_update": "2026-02-25T22:14:55Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:55Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.53},
                        {"name": "Vejle Boldklub", "price": 4.25},
                        {"name": "Draw", "price": 3.7},
                    ],
                }
            ],
        },
        {
            "key": "codere_it",
            "title": "Codere (IT)",
            "last_update": "2026-02-25T22:14:55Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:55Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.63},
                        {"name": "Vejle Boldklub", "price": 4.7},
                        {"name": "Draw", "price": 4.1},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:55Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.6, "point": 2.5},
                        {"name": "Under", "price": 2.14, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "betsson",
            "title": "Betsson",
            "last_update": "2026-02-25T22:13:46Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:46Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.65},
                        {"name": "Vejle Boldklub", "price": 4.8},
                        {"name": "Draw", "price": 4.05},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:13:46Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.65, "point": 2.5},
                        {"name": "Under", "price": 2.18, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "pmu_fr",
            "title": "PMU (FR)",
            "last_update": "2026-02-25T22:13:47Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:47Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.48},
                        {"name": "Vejle Boldklub", "price": 4.4},
                        {"name": "Draw", "price": 3.5},
                    ],
                }
            ],
        },
        {
            "key": "onexbet",
            "title": "1xBet",
            "last_update": "2026-02-25T22:14:26Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:26Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.63},
                        {"name": "Vejle Boldklub", "price": 4.92},
                        {"name": "Draw", "price": 4.0},
                    ],
                },
                {
                    "key": "spreads",
                    "last_update": "2026-02-25T22:14:26Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 2.57, "point": -1.5},
                        {"name": "Vejle Boldklub", "price": 1.41, "point": 1.5},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:26Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.66, "point": 2.5},
                        {"name": "Under", "price": 2.18, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "winamax_de",
            "title": "Winamax (DE)",
            "last_update": "2026-02-25T22:14:13Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:13Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.56},
                        {"name": "Vejle Boldklub", "price": 4.2},
                        {"name": "Draw", "price": 3.95},
                    ],
                }
            ],
        },
        {
            "key": "betclic_fr",
            "title": "Betclic (FR)",
            "last_update": "2026-02-25T22:13:15Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:15Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.53},
                        {"name": "Vejle Boldklub", "price": 4.25},
                        {"name": "Draw", "price": 3.7},
                    ],
                }
            ],
        },
        {
            "key": "winamax_fr",
            "title": "Winamax (FR)",
            "last_update": "2026-02-25T22:13:49Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:49Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.52},
                        {"name": "Vejle Boldklub", "price": 4.0},
                        {"name": "Draw", "price": 3.7},
                    ],
                }
            ],
        },
        {
            "key": "betfair_ex_eu",
            "title": "Betfair",
            "last_update": "2026-02-25T22:14:28Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:28Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.65},
                        {"name": "Vejle Boldklub", "price": 5.2},
                        {"name": "Draw", "price": 4.2},
                    ],
                },
                {
                    "key": "h2h_lay",
                    "last_update": "2026-02-25T22:14:28Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.72},
                        {"name": "Vejle Boldklub", "price": 5.8},
                        {"name": "Draw", "price": 4.7},
                    ],
                },
            ],
        },
        {
            "key": "draftkings",
            "title": "DraftKings",
            "last_update": "2026-02-25T22:14:54Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:54Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.61},
                        {"name": "Vejle Boldklub", "price": 4.8},
                        {"name": "Draw", "price": 4.0},
                    ],
                }
            ],
        },
        {
            "key": "sport888",
            "title": "888sport",
            "last_update": "2026-02-25T22:14:27Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:27Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.61},
                        {"name": "Vejle Boldklub", "price": 4.8},
                        {"name": "Draw", "price": 3.8},
                    ],
                }
            ],
        },
        {
            "key": "williamhill",
            "title": "William Hill",
            "last_update": "2026-02-25T22:14:00Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:00Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.62},
                        {"name": "Vejle Boldklub", "price": 4.8},
                        {"name": "Draw", "price": 3.8},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:00Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.62, "point": 2.5},
                        {"name": "Under", "price": 2.2, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "tipico_de",
            "title": "Tipico",
            "last_update": "2026-02-25T22:14:54Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:54Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.57},
                        {"name": "Vejle Boldklub", "price": 5.2},
                        {"name": "Draw", "price": 3.9},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:54Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.6, "point": 2.5},
                        {"name": "Under", "price": 2.2, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "suprabets",
            "title": "Suprabets",
            "last_update": "2026-02-25T22:14:41Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:41Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.62},
                        {"name": "Vejle Boldklub", "price": 4.75},
                        {"name": "Draw", "price": 3.91},
                    ],
                }
            ],
        },
        {
            "key": "gtbets",
            "title": "GTbets",
            "last_update": "2026-02-25T22:14:27Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:27Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.65},
                        {"name": "Vejle Boldklub", "price": 4.85},
                        {"name": "Draw", "price": 4.08},
                    ],
                },
                {
                    "key": "spreads",
                    "last_update": "2026-02-25T22:14:27Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.63, "point": -0.5},
                        {"name": "Vejle Boldklub", "price": 2.24, "point": 0.5},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:27Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.67, "point": 2.5},
                        {"name": "Under", "price": 2.17, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "bovada",
            "title": "Bovada",
            "last_update": "2026-02-25T22:14:00Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:00Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.57},
                        {"name": "Vejle Boldklub", "price": 4.9},
                        {"name": "Draw", "price": 4.1},
                    ],
                },
                {
                    "key": "spreads",
                    "last_update": "2026-02-25T22:14:00Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.98, "point": -1.0},
                        {"name": "Vejle Boldklub", "price": 1.85, "point": 1.0},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:00Z",
                    "outcomes": [
                        {"name": "Over", "price": 2.02, "point": 3.0},
                        {"name": "Under", "price": 1.82, "point": 3.0},
                    ],
                },
            ],
        },
        {
            "key": "everygame",
            "title": "Everygame",
            "last_update": "2026-02-25T22:13:02Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:02Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.62},
                        {"name": "Vejle Boldklub", "price": 4.75},
                        {"name": "Draw", "price": 3.9},
                    ],
                }
            ],
        },
        {
            "key": "leovegas_se",
            "title": "LeoVegas (SE)",
            "last_update": "2026-02-25T22:14:26Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:26Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.63},
                        {"name": "Vejle Boldklub", "price": 4.6},
                        {"name": "Draw", "price": 3.9},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:26Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.6, "point": 2.5},
                        {"name": "Under", "price": 2.12, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "unibet_nl",
            "title": "Unibet (NL)",
            "last_update": "2026-02-25T22:14:40Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:40Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.67},
                        {"name": "Vejle Boldklub", "price": 4.75},
                        {"name": "Draw", "price": 4.0},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:40Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.65, "point": 2.5},
                        {"name": "Under", "price": 2.18, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "unibet_se",
            "title": "Unibet (SE)",
            "last_update": "2026-02-25T22:14:55Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:55Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.67},
                        {"name": "Vejle Boldklub", "price": 4.75},
                        {"name": "Draw", "price": 4.0},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:55Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.65, "point": 2.5},
                        {"name": "Under", "price": 2.18, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "betparx",
            "title": "betPARX",
            "last_update": "2026-02-25T22:14:27Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:27Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.67},
                        {"name": "Vejle Boldklub", "price": 4.75},
                        {"name": "Draw", "price": 4.0},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:27Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.65, "point": 2.5},
                        {"name": "Under", "price": 2.18, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "betrivers",
            "title": "BetRivers",
            "last_update": "2026-02-25T22:13:59Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:59Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.66},
                        {"name": "Vejle Boldklub", "price": 4.7},
                        {"name": "Draw", "price": 4.0},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:13:59Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.64, "point": 2.5},
                        {"name": "Under", "price": 2.18, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "betmgm",
            "title": "BetMGM",
            "last_update": "2026-02-25T22:14:26Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:14:26Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.62},
                        {"name": "Vejle Boldklub", "price": 4.75},
                        {"name": "Draw", "price": 4.0},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:14:26Z",
                    "outcomes": [
                        {"name": "Over", "price": 1.61, "point": 2.5},
                        {"name": "Under", "price": 2.15, "point": 2.5},
                    ],
                },
            ],
        },
        {
            "key": "betus",
            "title": "BetUS",
            "last_update": "2026-02-25T22:13:59Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:59Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.6},
                        {"name": "Vejle Boldklub", "price": 4.7},
                        {"name": "Draw", "price": 3.95},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:13:59Z",
                    "outcomes": [
                        {"name": "Over", "price": 2.1, "point": 3.0},
                        {"name": "Under", "price": 1.71, "point": 3.0},
                    ],
                },
            ],
        },
        {
            "key": "coolbet",
            "title": "Coolbet",
            "last_update": "2026-02-25T22:13:19Z",
            "markets": [
                {
                    "key": "h2h",
                    "last_update": "2026-02-25T22:13:19Z",
                    "outcomes": [
                        {"name": "AGF Aarhus", "price": 1.67},
                        {"name": "Vejle Boldklub", "price": 5.0},
                        {"name": "Draw", "price": 4.0},
                    ],
                },
                {
                    "key": "totals",
                    "last_update": "2026-02-25T22:13:19Z",
                    "outcomes": [
                        {"name": "Over", "price": 2.03, "point": 3.0},
                        {"name": "Under", "price": 1.76, "point": 3.0},
                    ],
                },
            ],
        },
    ],
}

# %%
import pandas as pd
BETS = pd.DataFrame(columns=["sport", "team", "type", "point", "odds", "time"])

# get active sports

# get sport odds

# loop through games


# create table of game odds without juice, and the raw odds
def remove_juice(outcomes):
    outcomes_df = pd.DataFrame(outcomes)
    probs = 1 / outcomes_df["price"]
    fair_probs = probs / probs.sum()
    return outcomes_df.assign(fair_prob=fair_probs)


def game_odds(game):
    game_odds = pd.DataFrame(
        columns=[
            "sport",
            "h_team",
            "a_team",
            "book",
            "h_ml",
            "a_ml",
            "h_spread",
            "a_spread",
            "spreads_pt",
            "over",
            "under",
            "totals_pt",
        ]
    )
    index = 0
    sport = game["sport_key"]
    home_team = game["home_team"]
    away_team = game["away_team"]

    for book in game["bookmakers"]:
        game_odds.at[index, "book"] = book["key"]
        for market in book["markets"]:
            if market["key"] == "h2h":
                outcomes = remove_juice(market["outcomes"])
                home_row = outcomes[outcomes["name"] == home_team]
                away_row = outcomes[outcomes["name"] == away_team]
                game_odds.at[index, "h_ml"] = home_row["fair_prob"].item()
                game_odds.at[index, "a_ml"] = away_row["fair_prob"].item()
            if market["key"] == "spreads":
                outcomes = remove_juice(market["outcomes"])
                home_row = outcomes[outcomes["name"] == home_team]
                away_row = outcomes[outcomes["name"] == away_team]
                game_odds.at[index, "h_spread"] = home_row["fair_prob"].item()
                game_odds.at[index, "a_spread"] = away_row["fair_prob"].item()
                game_odds.at[index, "spreads_pt"] = home_row["point"].item()
            if market["key"] == "totals":
                outcomes = remove_juice(market["outcomes"])
                over_row = outcomes[outcomes["name"] == 'Over']
                under_row = outcomes[outcomes["name"] == 'Under']
                game_odds.at[index, "over"] = over_row["fair_prob"].item()
                game_odds.at[index, "under"] = under_row["fair_prob"].item()
                game_odds.at[index, "totals_pt"] = over_row["point"].item()
        index += 1
    return game_odds


# find fliff odds
def fliff_value(game_odds):
    fliff = game_odds[game_odds['book'] == 'fliff']
    
    if fliff['h_ml'] < game_odds['h_ml'].median():
        BETS.


# check if fliff odds better than (median odds - the edge)

# if so, save

# %%
odds = game_odds(game)

# %%
odds
# Out:
#    sport h_team a_team             book      h_ml      a_ml  h_spread  \
# 0    NaN    NaN    NaN         pinnacle  0.192338  0.574683  0.474093
# 1    NaN    NaN    NaN          fanduel  0.187392  0.578369       NaN
# 2    NaN    NaN    NaN        nordicbet  0.196299  0.571051       NaN
# 3    NaN    NaN    NaN      marathonbet  0.186721  0.579878       NaN
# 4    NaN    NaN    NaN  parionssport_fr  0.202987  0.563852       NaN
# 5    NaN    NaN    NaN        codere_it  0.198816  0.573273       NaN
# 6    NaN    NaN    NaN          betsson  0.196299  0.571051       NaN
# 7    NaN    NaN    NaN           pmu_fr    0.1912  0.568433       NaN
# 8    NaN    NaN    NaN          onexbet  0.190534  0.575109  0.645729
# 9    NaN    NaN    NaN       winamax_de  0.210278  0.566134       NaN
# 10   NaN    NaN    NaN       betclic_fr  0.202987  0.563852       NaN
# 11   NaN    NaN    NaN       winamax_fr  0.212194  0.558406       NaN
# 12   NaN    NaN    NaN    betfair_ex_eu  0.185542  0.584739       NaN
# 13   NaN    NaN    NaN       draftkings  0.192999  0.575402       NaN
# 14   NaN    NaN    NaN         sport888  0.190675  0.568472       NaN
# 15   NaN    NaN    NaN      williamhill  0.191347  0.566953       NaN
# 16   NaN    NaN    NaN        tipico_de  0.177134  0.586687       NaN
# 17   NaN    NaN    NaN        suprabets   0.19429  0.569679       NaN
# 18   NaN    NaN    NaN           gtbets  0.195003  0.573191  0.421189
# 19   NaN    NaN    NaN           bovada  0.188106  0.587084  0.516971
# 20   NaN    NaN    NaN        everygame  0.194173  0.569334       NaN
# 21   NaN    NaN    NaN      leovegas_se  0.199937   0.56424       NaN
# 22   NaN    NaN    NaN        unibet_nl  0.198736  0.565266       NaN
# 23   NaN    NaN    NaN        unibet_se  0.198736  0.565266       NaN
# 24   NaN    NaN    NaN          betparx  0.198736  0.565266       NaN
# 25   NaN    NaN    NaN        betrivers  0.199747   0.56555       NaN
# 26   NaN    NaN    NaN           betmgm  0.195328   0.57272       NaN
# 27   NaN    NaN    NaN            betus  0.195032  0.572905       NaN
# 28   NaN    NaN    NaN          coolbet  0.190694  0.570939       NaN
#
#     a_spread spreads_pt      over     under totals_pt
# 0   0.525907       0.75  0.509138  0.490862      2.75
# 1        NaN        NaN       NaN       NaN       NaN
# 2        NaN        NaN  0.569191  0.430809       2.5
# 3        NaN        NaN       NaN       NaN       NaN
# 4        NaN        NaN       NaN       NaN       NaN
# 5        NaN        NaN  0.572193  0.427807       2.5
# 6        NaN        NaN  0.569191  0.430809       2.5
# 7        NaN        NaN       NaN       NaN       NaN
# 8   0.354271        1.5  0.567708  0.432292       2.5
# 9        NaN        NaN       NaN       NaN       NaN
# 10       NaN        NaN       NaN       NaN       NaN
# 11       NaN        NaN       NaN       NaN       NaN
# 12       NaN        NaN       NaN       NaN       NaN
# 13       NaN        NaN       NaN       NaN       NaN
# 14       NaN        NaN       NaN       NaN       NaN
# 15       NaN        NaN  0.575916  0.424084       2.5
# 16       NaN        NaN  0.578947  0.421053       2.5
# 17       NaN        NaN       NaN       NaN       NaN
# 18  0.578811        0.5  0.565104  0.434896       2.5
# 19  0.483029        1.0  0.473958  0.526042       3.0
# 20       NaN        NaN       NaN       NaN       NaN
# 21       NaN        NaN  0.569892  0.430108       2.5
# 22       NaN        NaN  0.569191  0.430809       2.5
# 23       NaN        NaN  0.569191  0.430809       2.5
# 24       NaN        NaN  0.569191  0.430809       2.5
# 25       NaN        NaN  0.570681  0.429319       2.5
# 26       NaN        NaN  0.571809  0.428191       2.5
# 27       NaN        NaN  0.448819  0.551181       3.0
# 28       NaN        NaN   0.46438   0.53562       3.0
