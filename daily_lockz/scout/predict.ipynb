# %%
for rou in range(6):
    import warnings # type: ignore
    warnings.filterwarnings('ignore') # type: ignore
    from bs4 import BeautifulSoup # type: ignore
    from datetime import date, timedelta # type: ignore
    from dotenv import load_dotenv # type: ignore
    import numpy as np # type: ignore
    import os # type: ignore
    import pandas as pd # type: ignore
    from playwright.async_api import async_playwright, TimeoutError as PlaywrightTimeout # type: ignore
    import random # type: ignore
    from sklearn.model_selection import TimeSeriesSplit # type: ignore
    from sklearn.preprocessing import MinMaxScaler # type: ignore
    from sqlalchemy import create_engine # type: ignore
    import tensorflow as tf # type: ignore
    from tensorflow.keras import Model # type: ignore
    from tensorflow.keras.callbacks import EarlyStopping # type: ignore
    from tensorflow.keras.layers import Dense, Input # type: ignore
    import time # type: ignore

    SCHEDULE = './bracket.csv'
    FINAL_BRACKET = './predicted_bracket.csv'
    if rou == 0:
        try:
            # os.remove(SCHEDULE)
            os.remove(FINAL_BRACKET)
        except:
            pass

    async def get_html(url, selector, sleep=5, retries=5):
        html = None
        for i in range(1, retries + 1):
            time.sleep(sleep * i)
            try:
                async with async_playwright() as p:
                    browser = await p.webkit.launch()
                    page = await browser.new_page()
                    await page.goto(url)
                    if 'College Basketball at Sports-Reference.com' in str(await page.title()) and '404 error' not in str(await page.title()):
                        print(await page.title())
                    else:
                        print('INVALID PAGE')
                        return None
                    html = await page.inner_html(selector)
            except PlaywrightTimeout:
                print(f"Timeout error on {url}")
                continue
            else:
                break
        return html

    def get_schedule(html):
        schedule = pd.DataFrame()
        soup = BeautifulSoup(html)
        i = 0
        table = soup.find('div', {'id':'brackets'})
        brackets = table.find_all('div', id='bracket')
        for bracket in brackets[:4]:
            team = 0
            school_links = [a['href'] for a in bracket.find_all('a', href=lambda href: href and 'schools' in href)][:16]
            school_names = [a.text.strip() for a in bracket.find_all('a', href=lambda href: href and 'schools' in href)][:16]
            for _ in range(len(school_links) // 2):
                schedule.at[i, 'home_team'] = (school_links[2 * team].split('schools/')[-1].split('/men')[0] + ':' 
                                            + school_names[2 * team])
                schedule.at[i, 'away_team'] = (school_links[2 * team + 1].split('schools/')[-1].split('/men')[0] + ':'
                                            + school_names[2 * team + 1])
                i += 1
                team += 1
        if not os.path.isfile(SCHEDULE):
            print('Schedule Created')
            schedule.to_csv(SCHEDULE, mode='w')
            schedule.to_csv(FINAL_BRACKET, mode='w')
        else:
            schedule.to_csv(SCHEDULE, mode='a', header=False)
            schedule.to_csv(FINAL_BRACKET, mode='a', header=False)

    def remove_ncaa(school):
        school = str(school)
        school = school.split('\xa0')[0]
        return school

    if rou == 0:
        # html = await get_html('https://www.sports-reference.com/cbb/postseason/men/2024-ncaa.html', '#content')
        # get_schedule(html)
        pass

    html = await get_html('https://www.sports-reference.com/cbb/seasons/men/2025-ratings.html', '#content')
    soup = BeautifulSoup(html)
    srs = pd.read_html(str(soup), attrs={'id':'ratings'}, index_col=0)[0]
    srs.columns = srs.columns.droplevel(0)
    srs['School'] = srs['School'].apply(remove_ncaa)
    
    srs['SOS'] = pd.to_numeric(srs['SOS'], errors='coerce')
    srs['SOS'] = srs['SOS'] / 100
    
    srs['SRS'] = pd.to_numeric(srs['SRS'], errors='coerce')
    srs['SRS'] = srs['SRS'] / 100
    
    srs['NRtg'] = pd.to_numeric(srs['NRtg'], errors='coerce')
    srs['NRtg'] = srs['NRtg'] / 100
    
    srs['Pts'] = pd.to_numeric(srs['Pts'], errors='coerce')
    srs['Pts'] = srs['Pts'] / 100
    
    srs['OSRS'] = pd.to_numeric(srs['OSRS'], errors='coerce')
    srs['DSRS'] = pd.to_numeric(srs['DSRS'], errors='coerce')
    srs['ASRS'] = abs(srs['OSRS'] - srs['DSRS']) / 100

    load_dotenv()
    SQL_PASS = os.getenv('SQL_PASS')
    engine = create_engine(f"mysql+pymysql://root:{SQL_PASS}@localhost:3306/daily_lockz")

    DATE = date.today()
    SIM = int(1e5)

    random.seed(0)
    np.random.seed(0)
    tf.random.set_seed(0)
    pd.set_option('mode.use_inf_as_na', True)
    pd.set_option('display.max_rows', 10000)

    simulations = pd.DataFrame(columns=('sport','home_team','away_team','h_score','a_score','h_logo','a_logo','win_prob','implied_odds','time'))
    games = pd.read_csv(f"bracket.csv")

    df = pd.read_sql(f"SELECT * FROM ncaab_games", engine, index_col='index')
    df = df[df['date'] < pd.Timestamp('2025-03-18')]
    df['winner'] = (df['total'] > df['total_opp']).astype(int)
    df = df.sort_values('date').reset_index(drop=True)
    del df['index_opp']

    std = df['total'].std()
    df.fillna(value=0, inplace=True)

    last_update = df['date'].iloc[-1]
    num_games = len(df[df['date'] == str(last_update)]) // 2
    print(f"LAST GAMES UPDATE: {last_update} ({num_games} GAMES)")
            
    def add_targets(group):
        group['winner_target'] = group['winner'].shift(-1)
        return group
            
    df = df.groupby('team', group_keys=False).apply(add_targets)
    df['winner_target'][pd.isnull(df['winner_target'])] = 2
    df['winner_target'] = df['winner_target'].astype(int, errors='ignore')

    removed_columns = ['date','team','team_opp','logo','logo_opp','winner_target']
    selected_columns = df.columns[~df.columns.isin(removed_columns)]

    scaler = MinMaxScaler()
    df[selected_columns] = scaler.fit_transform(df[selected_columns])

    def shift_col(team, col_name):
        next_col = team[col_name].shift(-1)
        return next_col
        
    def add_col(df, col_name):
        return df.groupby('team', group_keys=False).apply(lambda x: shift_col(x, col_name))
            
    df['home_next'] = add_col(df, 'home')
    df['team_opp_next'] = add_col(df, 'team_opp')
    df['date_next'] = add_col(df, 'date')

    for i, game in games.iterrows():
        home_team = game['home_team'].split(':')[0]
        away_team = game['away_team'].split(':')[0]

        null_indices = df[(df['team'] == home_team) & (df['home_next'].isnull())].index
        for idx in null_indices:
            df.at[idx, 'home_next'] = 0
            df.at[idx, 'team_opp_next'] = away_team
            df.at[idx, 'date_next'] = DATE + timedelta(days=i)
        null_indices = df[(df['team'] == away_team) & (df['home_next'].isnull())].index
        for idx in null_indices:
            df.at[idx, 'home_next'] = 0
            df.at[idx, 'team_opp_next'] = home_team
            df.at[idx, 'date_next'] = DATE + timedelta(days=i)

    df_rolling2 = df[list(selected_columns) + ['team']]
    df_rolling4 = df[list(selected_columns) + ['team']]
    df_rolling8 = df[list(selected_columns) + ['team']]

    def find_team_averages2(team):
        rolling = team.rolling(2).mean(numeric_only=True)
        return rolling

    df_rolling2 = df_rolling2.groupby(['team'], group_keys=False).apply(find_team_averages2)
    rolling_cols2 = [f"{col}_2" for col in df_rolling2.columns]
    df_rolling2.columns = rolling_cols2

    def find_team_averages4(team):
        rolling = team.rolling(4).mean(numeric_only=True)
        return rolling
                
    df_rolling4 = df_rolling4.groupby(['team'], group_keys=False).apply(find_team_averages4)
    rolling_cols4 = [f"{col}_4" for col in df_rolling4.columns]
    df_rolling4.columns = rolling_cols4

    def find_team_averages8(team):
        rolling = team.rolling(8).mean(numeric_only=True)
        return rolling
        
    df_rolling8 = df_rolling8.groupby(['team'], group_keys=False).apply(find_team_averages8)
    rolling_cols8 = [f"{col}_8" for col in df_rolling8.columns]
    df_rolling8.columns = rolling_cols8

    df = pd.concat([df, df_rolling2], axis=1)
    df = pd.concat([df, df_rolling4], axis=1)
    df = pd.concat([df, df_rolling8], axis=1)

    df = df.dropna()
    full = df.merge(df[rolling_cols2 + rolling_cols4 + rolling_cols8 +
                    ['team_opp_next','date_next','team']], 
                    left_on=['team','date_next'], 
                    right_on=['team_opp_next','date_next'])
    print(f"COLUMNS USED: {len(full.columns)}")
    print(f"\n\n\nROUND {rou+1}\n\n\n")

    removed_columns = list(full.columns[full.dtypes != 'float']) + removed_columns
    selected_columns = full.columns[~full.columns.isin(removed_columns)]

    train_df = full[full['winner_target'] != 2]
    X = train_df[selected_columns].values
    y_winner = train_df['winner_target'].values

    input_layer = Input(shape=(len(selected_columns),))

    layer1 = Dense(256, activation='relu')(input_layer)
    layer2 = Dense(128, activation='relu')(layer1)
    layer3 = Dense(64, activation='relu')(layer2)

    output_winner = Dense(1, activation='sigmoid', name='winner_output')(layer3)
    model = Model(inputs=input_layer, outputs=output_winner)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    split = TimeSeriesSplit(n_splits=5)
    early_stopping = EarlyStopping(patience=25)
    for train_index, test_index in split.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y_winner[train_index], y_winner[test_index]

        model.fit(X_train, y_train,
                epochs=125,
                verbose=0,
                callbacks=[early_stopping],
                validation_data=(X_test, y_test))
        
    test_predictions = model.predict(X_test)
    test_predictions = (test_predictions > 0.5).astype(int)
    accuracy = np.mean(test_predictions.flatten() == y_test)
    print(f"Test Accuracy: {accuracy:.5f}")

    predictions = model.predict(full[selected_columns])
    full['winner_pred'] = predictions

    fix_count = 0
    WINNERS = []
    for i, game in games.iterrows():
        home_team = game['home_team'].split(':')[0]
        away_team = game['away_team'].split(':')[0]

        scores = full[((full['team_x'] == home_team) & (full['winner_target'] == 2)) |
                    ((full['team_x'] == away_team) & (full['winner_target'] == 2))
                    ].reset_index()
        print(scores[['winner_pred','team_x']])

        if scores['winner_pred'].iloc[0] >= scores['winner_pred'].iloc[1]:
            win = 0
            lose = 1
        else:
            win = 1
            lose = 0
            
        win_team = scores['team_x'].iloc[win]
        lose_team = scores['team_x'].iloc[lose]
        win_score = scores['winner_pred'].iloc[win]
        lose_score = scores['winner_pred'].iloc[lose]
        
        extra_adj = True
        upset = 5 / (rou + 1)
        if win_score < 0.5 and lose_score < 0.5:
            lose_score += (win_score - lose_score) * upset 
            extra_adj = False

        if win_team == home_team:
            win_team = game['home_team'].split(':')[-1]
            lose_team = game['away_team'].split(':')[-1]
            add = 'HOME'
        else:
            win_team = game['away_team'].split(':')[-1]
            lose_team = game['home_team'].split(':')[-1]
            add = 'AWAY'
        
        team_convert = {
            'UConn':'Connecticut',
            'VCU':'Virginia Commonwealth',
            'Saint Mary\'s':'Saint Mary\'s (CA)',
            'USC':'Southern California',
            'Pitt':'Pittsburgh',
            'UCSB':'UC Santa Barbara',
            'UNC':'North Carolina',
            'BYU':'Brigham Young',
            'St. Peter\'s':'Saint Peter\'s'
        }
        if win_team in team_convert:
            win_team = team_convert[win_team]
        if lose_team in team_convert:
            lose_team = team_convert[lose_team]
                
        adjusted = srs[srs['School'] == win_team]
        if adjusted.empty:
            print(f"FIX {win_team}")
            fix_count += 1
        else:
            win_score += float(adjusted['SOS'])
            win_score += float(adjusted['SRS'])
            win_score += float(adjusted['NRtg'])
            win_score += float(adjusted['Pts'])
            win_score -= float(adjusted['ASRS']) / (rou + 1)
        adjusted = None
            
        adjusted = srs[srs['School'] == lose_team]
        if adjusted.empty:
            print(f"FIX {lose_team}")
            fix_count += 1
        else:
            lose_score += float(adjusted['SOS'])
            lose_score += float(adjusted['SRS'])
            lose_score += float(adjusted['NRtg'])
            lose_score += float(adjusted['Pts'])
            lose_score -= float(adjusted['ASRS']) / (rou + 1)
        adjusted = None
        
        print(f"\n{win_team} ADJUSTED SCORE: {win_score}")
        print(f"{lose_team} ADJUESTED SCORE: {lose_score}")
        
        if extra_adj:
            if rou == 0:
                no_change = not scores['winner_pred'].iloc[win] - scores['winner_pred'].iloc[lose] > abs(win_score - lose_score)
            else:
                no_change = True
            if no_change and (lose_score > win_score):
                win_team, lose_team = lose_team, win_team
                if add == 'HOME':
                    add = 'AWAY'
                else:
                    add = 'HOME'
        else:
            if lose_score > win_score:
                win_team, lose_team = lose_team, win_team
                if add == 'HOME':
                    add = 'AWAY'
                else:
                    add = 'HOME'
        
        print(f"WIN TEAM: {win_team}\n")
        if add == 'AWAY':
            WINNERS.append(f"{game['away_team'].split(':')[0]}:{game['away_team'].split(':')[-1]}")
        else:
            WINNERS.append(f"{game['home_team'].split(':')[0]}:{game['home_team'].split(':')[-1]}")
    
    bracket = pd.DataFrame()
    for g in range((len(WINNERS) // 2)):
        bracket.at[g, 'home_team'] = WINNERS[2*g]
        bracket.at[g, 'away_team'] = WINNERS[2*g+1]
    bracket.to_csv(SCHEDULE)
    bracket.to_csv(FINAL_BRACKET, mode='a', header=False)      
        
    print(f"{fix_count} FIXES NEEDED")
    # %reset -f
# Out:
# 2024-25 Men's College Basketball School Ratings | College Basketball at Sports-Reference.com
# LAST GAMES UPDATE: 2025-03-16 00:00:00 (3 GAMES)
# COLUMNS USED: 1152
#
#
#
# ROUND 1
#
#
#
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step
# Test Accuracy: 0.68169
# 805/805 ━━━━━━━━━━━━━━━━━━━━ 0s 371us/step
#    winner_pred         team_x
# 0     0.386972  alabama-state
# 1     0.496719         auburn
#
# Auburn ADJUSTED SCORE: 2.1378186450958254
# Alabama State ADJUESTED SCORE: 1.3554047080993652
# WIN TEAM: Auburn
#
#    winner_pred      team_x
# 0     0.332754  louisville
# 1     0.407079   creighton
#
# Creighton ADJUSTED SCORE: 1.6622787429809571
# Louisville ADJUESTED SCORE: 2.030677770423889
# WIN TEAM: Louisville
#
#    winner_pred                team_x
# 0     0.094677              michigan
# 1     0.670500  california-san-diego
#
# UC San Diego ADJUSTED SCORE: 1.7091000996589658
# Michigan ADJUESTED SCORE: 1.4580766212582588
# WIN TEAM: UC San Diego
#
#    winner_pred    team_x
# 0     0.329933  texas-am
# 1     0.508029      yale
#
# Yale ADJUSTED SCORE: 1.4174289840698242
# Texas A&M ADJUESTED SCORE: 1.6452325704574584
# WIN TEAM: Texas A&M
#
#    winner_pred          team_x
# 0     0.155555     mississippi
# 1     0.666106  north-carolina
#
# North Carolina ADJUSTED SCORE: 1.907805568408966
# Mississippi ADJUESTED SCORE: 1.4723548310279848
# WIN TEAM: North Carolina
#
#    winner_pred      team_x
# 0     0.352898    lipscomb
# 1     0.237538  iowa-state
#
# Lipscomb ADJUSTED SCORE: 1.1962983891010284
# Iowa State ADJUESTED SCORE: 2.2608389523029326
# WIN TEAM: Iowa State
#
#    winner_pred      team_x
# 0     0.385822  new-mexico
# 1     0.257564   marquette
#
# New Mexico ADJUSTED SCORE: 1.5271217597007753
# Marquette ADJUESTED SCORE: 2.2215516926765444
# WIN TEAM: Marquette
#
#    winner_pred          team_x
# 0     0.304597  michigan-state
# 1     0.411163          bryant
#
# Bryant ADJUSTED SCORE: 1.0174625254154206
# Michigan State ADJUESTED SCORE: 2.2518227583408357
# WIN TEAM: Michigan State
#
#    winner_pred         team_x
# 0     0.291047  norfolk-state
# 1     0.576219        florida
#
# Florida ADJUSTED SCORE: 2.144218843460083
# Norfolk State ADJUESTED SCORE: 0.9007473048686981
# WIN TEAM: Florida
#
#    winner_pred       team_x
# 0     0.223666     oklahoma
# 1     0.549299  connecticut
#
# Connecticut ADJUSTED SCORE: 1.839699418926239
# Oklahoma ADJUESTED SCORE: 1.4406655354499818
# WIN TEAM: Connecticut
#
#    winner_pred          team_x
# 0     0.379484         memphis
# 1     0.408350  colorado-state
#
# Colorado State ADJUSTED SCORE: 1.5374504974842071
# Memphis ADJUESTED SCORE: 1.6240159000873566
# WIN TEAM: Memphis
#
#    winner_pred        team_x
# 0     0.310613      maryland
# 1     0.436160  grand-canyon
#
# Grand Canyon ADJUSTED SCORE: 1.2811600279808044
# Maryland ADJUESTED SCORE: 2.386249783420563
# WIN TEAM: Maryland
#
#    winner_pred    team_x
# 0     0.611076     drake
# 1     0.288454  missouri
#
# Drake ADJUSTED SCORE: 1.3714761165618898
# Missouri ADJUESTED SCORE: 1.6228541451930998
# WIN TEAM: Drake
#
#    winner_pred                     team_x
# 0     0.396622  north-carolina-wilmington
# 1     0.313626                 texas-tech
#
# UNC Wilmington ADJUSTED SCORE: 1.2061216444969178
# Texas Tech ADJUESTED SCORE: 2.199702945804596
# WIN TEAM: Texas Tech
#
#    winner_pred    team_x
# 0     0.386177    kansas
# 1     0.390285  arkansas
#
# Arkansas ADJUSTED SCORE: 1.663685462141037
# Kansas ADJUESTED SCORE: 1.8045212045192718
# WIN TEAM: Kansas
#
#    winner_pred          team_x
# 0     0.381334  nebraska-omaha
# 1     0.396307     st-johns-ny
#
# St. John's (NY) ADJUSTED SCORE: 1.7900066339492797
# Omaha ADJUESTED SCORE: 1.1304966657638549
# WIN TEAM: St. John's (NY)
#
#    winner_pred          team_x
# 0     0.299216  mount-st-marys
# 1     0.612983            duke
# FIX Mount St. Mary’s
#
# Duke ADJUSTED SCORE: 2.2593831671714786
# Mount St. Mary’s ADJUESTED SCORE: 0.2992158532142639
# WIN TEAM: Duke
#
#    winner_pred             team_x
# 0     0.342479             baylor
# 1     0.381161  mississippi-state
#
# Mississippi State ADJUSTED SCORE: 1.6682609148979186
# Baylor ADJUESTED SCORE: 1.902589446735382
# WIN TEAM: Baylor
#
#    winner_pred   team_x
# 0     0.345006   oregon
# 1     0.309583  liberty
#
# Oregon ADJUSTED SCORE: 1.6445058698654176
# Liberty ADJUESTED SCORE: 1.394595885658264
# WIN TEAM: Oregon
#
#    winner_pred   team_x
# 0     0.563626    akron
# 1     0.296904  arizona
#
# Akron ADJUSTED SCORE: 1.3194260509490967
# Arizona ADJUESTED SCORE: 1.7187044148921968
# WIN TEAM: Arizona
#
#    winner_pred                 team_x
# 0     0.313300          brigham-young
# 1     0.352772  virginia-commonwealth
#
# Virginia Commonwealth ADJUSTED SCORE: 1.4561716100215911
# Brigham Young ADJUESTED SCORE: 1.8228564462184904
# WIN TEAM: Brigham Young
#
#    winner_pred     team_x
# 0     0.357150  wisconsin
# 1     0.339413    montana
#
# Wisconsin ADJUSTED SCORE: 1.7440496605873108
# Montana ADJUESTED SCORE: 1.1029969500541688
# WIN TEAM: Wisconsin
#
#    winner_pred          team_x
# 0     0.486263  saint-marys-ca
# 1     0.300880      vanderbilt
#
# Saint Mary's (CA) ADJUSTED SCORE: 1.5775631857395171
# Vanderbilt ADJUESTED SCORE: 2.4031951538562772
# WIN TEAM: Vanderbilt
#
#    winner_pred         team_x
# 0     0.481509  robert-morris
# 1     0.277021        alabama
#
# Robert Morris ADJUSTED SCORE: 1.1827092086791993
# Alabama ADJUESTED SCORE: 2.755361722373962
# WIN TEAM: Alabama
#
#    winner_pred                          team_x
# 0     0.336564  southern-illinois-edwardsville
# 1     0.418349                         houston
#
# Houston ADJUSTED SCORE: 1.8657487594127655
# SIU Edwardsville ADJUESTED SCORE: 1.1770881370067596
# WIN TEAM: Houston
#
#    winner_pred   team_x
# 0     0.674083  gonzaga
# 1     0.181612  georgia
#
# Gonzaga ADJUSTED SCORE: 2.062583054065704
# Georgia ADJUESTED SCORE: 1.4235121339797971
# WIN TEAM: Gonzaga
#
#    winner_pred         team_x
# 0     0.481417  mcneese-state
# 1     0.329510        clemson
#
# McNeese State ADJUSTED SCORE: 1.4111173579216003
# Clemson ADJUESTED SCORE: 2.3465470147132876
# WIN TEAM: Clemson
#
#    winner_pred      team_x
# 0     0.196277      purdue
# 1     0.600143  high-point
#
# High Point ADJUSTED SCORE: 1.4369427769660952
# Purdue ADJUESTED SCORE: 1.6094772905826567
# WIN TEAM: High Point
#
#    winner_pred    team_x
# 0     0.328673  illinois
# 1     0.386434    xavier
#
# Xavier ADJUSTED SCORE: 1.5779344656467438
# Illinois ADJUESTED SCORE: 1.972181976747513
# WIN TEAM: Illinois
#
#    winner_pred    team_x
# 0     0.585955      troy
# 1     0.239637  kentucky
#
# Troy ADJUSTED SCORE: 1.324755023765564
# Kentucky ADJUESTED SCORE: 1.6118370619535445
# WIN TEAM: Troy
#
#    winner_pred      team_x
# 0     0.398236        ucla
# 1     0.353512  utah-state
#
# UCLA ADJUSTED SCORE: 1.6410356786727904
# Utah State ADJUESTED SCORE: 1.704431986618042
# WIN TEAM: Utah State
#
#    winner_pred     team_x
# 0     0.403477    wofford
# 1     0.293899  tennessee
#
# Wofford ADJUSTED SCORE: 1.106076983308792
# Tennessee ADJUESTED SCORE: 2.2073880833148958
# WIN TEAM: Tennessee
#
# 1 FIXES NEEDED
# 2024-25 Men's College Basketball School Ratings | College Basketball at Sports-Reference.com
# LAST GAMES UPDATE: 2025-03-16 00:00:00 (3 GAMES)
# COLUMNS USED: 1152
#
#
#
# ROUND 2
#
#
#
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step
# Test Accuracy: 0.68169
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
#    winner_pred      team_x
# 0     0.347002  louisville
# 1     0.525400      auburn
#
# Auburn ADJUSTED SCORE: 2.1979504001617434
# Louisville ADJUESTED SCORE: 1.684152327442169
# WIN TEAM: Auburn
#
#    winner_pred                team_x
# 0     0.157843              texas-am
# 1     0.665330  california-san-diego
#
# UC San Diego ADJUSTED SCORE: 1.7297304696083067
# Texas A&M ADJUESTED SCORE: 1.5005434258699415
# WIN TEAM: UC San Diego
#
#    winner_pred          team_x
# 0     0.235825      iowa-state
# 1     0.588833  north-carolina
#
# North Carolina ADJUSTED SCORE: 1.8870834512710573
# Iowa State ADJUESTED SCORE: 1.6927247488737107
# WIN TEAM: North Carolina
#
#    winner_pred          team_x
# 0     0.572720  michigan-state
# 1     0.234073       marquette
#
# Michigan State ADJUSTED SCORE: 1.9999698123931886
# Marquette ADJUESTED SCORE: 1.5606234601020814
# WIN TEAM: Michigan State
#
#    winner_pred       team_x
# 0     0.292125  connecticut
# 1     0.337966      florida
#
# Florida ADJUSTED SCORE: 1.943866024875641
# Connecticut ADJUESTED SCORE: 1.698476911664009
# WIN TEAM: Florida
#
#    winner_pred    team_x
# 0     0.375060   memphis
# 1     0.335143  maryland
#
# Memphis ADJUSTED SCORE: 1.5059604391098023
# Maryland ADJUESTED SCORE: 1.8905373131990435
# WIN TEAM: Maryland
#
#    winner_pred      team_x
# 0     0.537481       drake
# 1     0.306159  texas-tech
#
# Drake ADJUSTED SCORE: 1.3911807715415956
# Texas Tech ADJUESTED SCORE: 1.7934094069004058
# WIN TEAM: Texas Tech
#
#    winner_pred       team_x
# 0     0.180298       kansas
# 1     0.555094  st-johns-ny
#
# St. John's (NY) ADJUSTED SCORE: 1.950593765258789
# Kansas ADJUESTED SCORE: 1.5823982240915297
# WIN TEAM: St. John's (NY)
#
#    winner_pred  team_x
# 0     0.223555  baylor
# 1     0.653173    duke
#
# Duke ADJUSTED SCORE: 2.3109229102134705
# Baylor ADJUESTED SCORE: 1.5940048794269563
# WIN TEAM: Duke
#
#    winner_pred   team_x
# 0     0.540760   oregon
# 1     0.322336  arizona
#
# Oregon ADJUSTED SCORE: 1.8430097422599794
# Arizona ADJUESTED SCORE: 1.7897857796669008
# WIN TEAM: Oregon
#
#    winner_pred         team_x
# 0     0.336746      wisconsin
# 1     0.344194  brigham-young
#
# Brigham Young ADJUSTED SCORE: 1.6932438161849974
# Wisconsin ADJUESTED SCORE: 1.7584655743598938
# WIN TEAM: Wisconsin
#
#    winner_pred      team_x
# 0     0.299052  vanderbilt
# 1     0.365592     alabama
#
# Alabama ADJUSTED SCORE: 1.938541675043106
# Vanderbilt ADJUESTED SCORE: 1.6828013663530348
# WIN TEAM: Alabama
#
#    winner_pred   team_x
# 0     0.554219  gonzaga
# 1     0.213686  houston
#
# Gonzaga ADJUSTED SCORE: 1.9971690074920652
# Houston ADJUESTED SCORE: 1.728836242699623
# WIN TEAM: Gonzaga
#
#    winner_pred      team_x
# 0     0.361936  high-point
# 1     0.487037     clemson
#
# Clemson ADJUSTED SCORE: 1.7664865262031557
# High Point ADJUESTED SCORE: 1.5429376239776613
# WIN TEAM: Clemson
#
#    winner_pred    team_x
# 0     0.344029  illinois
# 1     0.379726      troy
#
# Troy ADJUSTED SCORE: 1.1536764099121095
# Illinois ADJUESTED SCORE: 1.8500227342844011
# WIN TEAM: Illinois
#
#    winner_pred      team_x
# 0     0.377605  utah-state
# 1     0.319842   tennessee
#
# Utah State ADJUSTED SCORE: 1.5458051700115205
# Tennessee ADJUESTED SCORE: 1.8907493724823
# WIN TEAM: Tennessee
#
# 0 FIXES NEEDED
# 2024-25 Men's College Basketball School Ratings | College Basketball at Sports-Reference.com
# LAST GAMES UPDATE: 2025-03-16 00:00:00 (3 GAMES)
# COLUMNS USED: 1152
#
#
#
# ROUND 3
#
#
#
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# Test Accuracy: 0.68169
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 0s 387us/step
#    winner_pred                team_x
# 0     0.404349  california-san-diego
# 1     0.318790                auburn
#
# UC San Diego ADJUSTED SCORE: 1.477348701238632
# Auburn ADJUESTED SCORE: 2.1444212755680083
# WIN TEAM: Auburn
#
#    winner_pred          team_x
# 0     0.323337  michigan-state
# 1     0.427707  north-carolina
#
# North Carolina ADJUSTED SCORE: 1.7448074933052062
# Michigan State ADJUESTED SCORE: 1.9288214213371278
# WIN TEAM: Michigan State
#
#    winner_pred    team_x
# 0     0.209754  maryland
# 1     0.446031   florida
#
# Florida ADJUSTED SCORE: 2.0645640395005547
# Maryland ADJUESTED SCORE: 2.0617152927716575
# WIN TEAM: Florida
#
#    winner_pred       team_x
# 0     0.292258   texas-tech
# 1     0.421757  st-johns-ny
#
# St. John's (NY) ADJUSTED SCORE: 1.8178571318149566
# Texas Tech ADJUESTED SCORE: 2.0007230644702916
# WIN TEAM: Texas Tech
#
#    winner_pred  team_x
# 0     0.335619  oregon
# 1     0.361703    duke
#
# Duke ADJUSTED SCORE: 2.0232362523396814
# Oregon ADJUESTED SCORE: 1.6822586844762166
# WIN TEAM: Duke
#
#    winner_pred     team_x
# 0     0.356871  wisconsin
# 1     0.314754    alabama
#
# Wisconsin ADJUSTED SCORE: 1.7653707406520844
# Alabama ADJUESTED SCORE: 1.9969149699687958
# WIN TEAM: Alabama
#
#    winner_pred   team_x
# 0     0.444938  gonzaga
# 1     0.322026  clemson
#
# Gonzaga ADJUSTED SCORE: 1.906038391447067
# Clemson ADJUESTED SCORE: 1.813646901146571
# WIN TEAM: Gonzaga
#
#    winner_pred     team_x
# 0     0.344976   illinois
# 1     0.304721  tennessee
#
# Illinois ADJUSTED SCORE: 1.7824097883065542
# Tennessee ADJUESTED SCORE: 1.8186134264151255
# WIN TEAM: Tennessee
#
# 0 FIXES NEEDED
# 2024-25 Men's College Basketball School Ratings | College Basketball at Sports-Reference.com
# LAST GAMES UPDATE: 2025-03-16 00:00:00 (3 GAMES)
# COLUMNS USED: 1152
#
#
#
# ROUND 4
#
#
#
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step
# Test Accuracy: 0.68169
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 0s 389us/step
#    winner_pred          team_x
# 0     0.323974  michigan-state
# 1     0.504766          auburn
#
# Auburn ADJUSTED SCORE: 2.193040510559082
# Michigan State ADJUESTED SCORE: 1.7576489537239075
# WIN TEAM: Auburn
#
#    winner_pred      team_x
# 0     0.275405  texas-tech
# 1     0.535368     florida
#
# Florida ADJUSTED SCORE: 2.160218382930756
# Texas Tech ADJUESTED SCORE: 1.7707296320915222
# WIN TEAM: Florida
#
#    winner_pred   team_x
# 0     0.594601     duke
# 1     0.177824  alabama
#
# Duke ADJUSTED SCORE: 2.258026333141327
# Alabama ADJUESTED SCORE: 1.8092989905834198
# WIN TEAM: Duke
#
#    winner_pred     team_x
# 0     0.597660    gonzaga
# 1     0.207598  tennessee
#
# Gonzaga ADJUSTED SCORE: 2.0678352435111997
# Tennessee ADJUESTED SCORE: 1.66454779214859
# WIN TEAM: Gonzaga
#
# 0 FIXES NEEDED
# 2024-25 Men's College Basketball School Ratings | College Basketball at Sports-Reference.com
# LAST GAMES UPDATE: 2025-03-16 00:00:00 (3 GAMES)
# COLUMNS USED: 1152
#
#
#
# ROUND 5
#
#
#
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step
# Test Accuracy: 0.68169
# 804/804 ━━━━━━━━━━━━━━━━━━━━ 0s 379us/step
#    winner_pred   team_x
# 0     0.269185   auburn
# 1     0.408038  florida
#
# Florida ADJUSTED SCORE: 2.0366777221107486
# Auburn ADJUESTED SCORE: 2.0994577221107487
# WIN TEAM: Auburn
#
#    winner_pred   team_x
# 0     0.368578  gonzaga
# 1     0.320461     duke
#
# Gonzaga ADJUSTED SCORE: 1.844198404188156
# Duke ADJUESTED SCORE: 2.0331384041881564
# WIN TEAM: Duke
#
# 0 FIXES NEEDED
# 2024-25 Men's College Basketball School Ratings | College Basketball at Sports-Reference.com
# LAST GAMES UPDATE: 2025-03-16 00:00:00 (3 GAMES)
# COLUMNS USED: 1152
#
#
#
# ROUND 6
#
#
#
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# Test Accuracy: 0.68169
# 803/803 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step
#    winner_pred  team_x
# 0     0.410932    duke
# 1     0.199661  auburn
#
# Duke ADJUSTED SCORE: 2.076249088350932
# Auburn ADJUESTED SCORE: 2.0692371874809266
# WIN TEAM: Duke
#
# 0 FIXES NEEDED
