# %%
import pandas as pd

# %%
pd.read_csv('../../../Downloads/NameUsage.tsv', sep='\t', nrows=1000)
# Out:
#     col:ID  col:alternativeID  col:nameAlternativeID  col:sourceID  \
# 0    673FW                NaN                    NaN        2232.0
# 1    9L2J9                NaN                    NaN        2232.0
# 2    95TZM                NaN                    NaN       55434.0
# 3     T95H                NaN                    NaN        1068.0
# 4    88PX6                NaN                    NaN        1101.0
# ..     ...                ...                    ...           ...
# 995  5R7ZF                NaN                    NaN      170394.0
# 996  8GPVC                NaN                    NaN        1008.0
# 997  C2XQS                NaN                    NaN        2302.0
# 998  BRJRX                NaN                    NaN        1032.0
# 999  4M4FZ                NaN                    NaN        1108.0
#
#     col:parentID col:basionymID         col:status  \
# 0          3CP83          3CP83            synonym
# 1          3F5B8          3F5B8            synonym
# ...
